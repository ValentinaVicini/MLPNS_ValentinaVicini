# %% [markdown]
# <a href="https://colab.research.google.com/github/ValentinaVicini/MLPNS_ValentinaVicini/blob/main/prova/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import skimage.io as io
import pylab as pl
from sklearn.cluster import KMeans

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/MyDrive/Colab Notebooks
# Out:
# /content/drive/MyDrive/Colab Notebooks

# %%
img = io.imread("croce.jpg")

# %%
img.shape
# Out:
# (2448, 3264, 3)

# %%
pl.imshow(img)

# %%
cimg = KMeans(n_clusters = 7, random_state = 777).fit(img.reshape(img.shape[0] * img.shape[1], 3))

# %%
pl.imshow(cimg.labels_.reshape(img.shape[:2]))
